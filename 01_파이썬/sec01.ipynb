# %%
print("hello world")
# Out:
# hello world

# %%
# 문자출력
print("안녕, 한국직업교육학원")
# Out:
# 안녕, 한국직업교육학원

# %%
# 숫자출력
print(100)
print("100")
a=100
b="100"
print(a==b)
# Out:
# 100
# 100
# False

# %%
# 산술 연산자 

print(100+200)
print(100-200)
print(100*200)
# Out:
# 300
# -100
# 20000

# %%
# 나머지 연산자 
print(10%3)
print(10/3)

# 거듭제곱 
print(10**2)

# 제곱근 
print(100**0.5)
# Out:
# 1
# 3.3333333333333335
# 100
# 10.0

# %%
# 산술연산자 우선순위
print((4+3)*5)
# Out:
# 35

# %%
# 문자 더하기
print("안녕"+"하세요")
print("안녕"*3)

# 문자 + 숫자 
print("안녕" + 100)
# Out:
# 안녕하세요
# 안녕안녕안녕
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[22], line 6
#       3 print("안녕"*3)
#       5 # 문자 + 숫자
# ----> 6 print("안녕" + 100)
#
# TypeError: can only concatenate str (not "int") to str

# %%
### 자료형

# %%
# 정수형

type(100)
# Out:
# int

# %%
# 실수형
type(100.0)
# Out:
# float

# %%
# 문자열
type("안녕하세요")
# Out:
# str
