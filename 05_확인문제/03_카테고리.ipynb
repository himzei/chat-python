# %%
import pandas as pd 
df = pd.read_csv("type1_data1.csv")

# 1. "subscribed" 컬럼에서 가장 빈도수가 많은 날짜를 구하시오.
# 2. 앞에서 구한 날짜의 일(day) 값을 정수로 구하시오.

# %%
mode_date = df["subscribed"].mode()[0]

# %%
mode_date[8:]
mode_date[-2:]
# Out:
# '17'

# %%
df["subscribed"].value_counts()
# Out:
# C:\Users\krcea\AppData\Local\Temp\ipykernel_10536\3524665269.py:1: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   df["subscribed"].value_counts()[0]
# np.int64(16)

# %%
df["subscribed"] =pd.to_datetime(df["subscribed"])
result = df["subscribed"].mode()
result.dt.day[0]
# Out:
# np.int32(17)
